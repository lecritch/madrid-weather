# %% [markdown]
# <a href="https://colab.research.google.com/github/dlevonian/madrid-weather/blob/master/madrid_temperature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# The data consists of the daily meteorological measurements taken at Madrid Barajas Airport for 19 years, from Jan 1 1997 to Dec 31 2015 ([Kaggle source](https://www.kaggle.com/juliansimon/weather_madrid_lemd_1997_2015.csv)).
#
#
# The objective is to identify the best ML framework that minimizes the mean absolute error of predictions, using both univariate (purely autorgressive) and multivariate models.
#
# In this notebook, we explore the correlation between different forecasts (e.g. SARIMA and RNNs) and the accuracy of ensemble models.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

import math
from scipy import stats

import time
from datetime import datetime

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

import warnings
warnings.simplefilter(action='ignore')

# %%
# must install statsmodels v0.12 or higher to run statsmodels.tsa.arima.model
# !pip install git+https://github.com/statsmodels/statsmodels

# %%
import statsmodels
statsmodels.__version__
# Out:
# '0.13.0.dev0+2.g54f7c05be'

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.graphics.api import qqplot
from statsmodels.tsa.arima.model import ARIMA

from sklearn.metrics import mean_absolute_error as MAE
from sklearn.preprocessing import StandardScaler

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LSTM

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import callbacks

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
path = '/content/drive/My Drive/DLA/Madrid_weather/'
# Out:
# Mounted at /content/drive

# %%
SEED=2020
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ### Load, preprocess

# %%
df = pd.read_csv(path+'data/weather_madrid_LEMD_1997_2015.csv')
print(df.shape)
df.sample(5).T
# Out:
# (6812, 23)
#                                    1331       2845  ...       1308       5153
# CET                          2000-11-29  2005-2-20  ...  2000-11-6  2011-6-17
# Max TemperatureC                     14         11  ...         15         31
# Mean TemperatureC                    11          6  ...         11         22
# Min TemperatureC                      8          2  ...          8         14
# Dew PointC                            9         -2  ...         13         11
# MeanDew PointC                        8         -3  ...          4          8
# Min DewpointC                         5         -6  ...         -1          5
# Max Humidity                         94         70  ...         94         77
#  Mean Humidity                       82         51  ...         65         40
#  Min Humidity                        58         30  ...         41         19
#  Max Sea Level PressurehPa         1019       1019  ...       1006       1017
#  Mean Sea Level PressurehPa        1015       1015  ...       1003       1015
#  Min Sea Level PressurehPa         1012       1009  ...        999       1013
#  Max VisibilityKm                    10         10  ...         10        NaN
#  Mean VisibilityKm                    9         10  ...         10        NaN
#  Min VisibilitykM                     6         10  ...          4        NaN
#  Max Wind SpeedKm/h                  27         24  ...         47         24
#  Mean Wind SpeedKm/h                 13         11  ...         29         10
#  Max Gust SpeedKm/h                 NaN         34  ...        NaN         52
# Precipitationmm                       0          0  ...          0          0
#  CloudCover                           5          4  ...          5        NaN
#  Events                            Rain        NaN  ...       Rain        NaN
# WindDirDegrees                      221        323  ...        260        275
#
# [23 rows x 5 columns]

# %%
rename_dict =  {'CET'                           :'date',
                'Max TemperatureC'              :'temperature_max',
                'Mean TemperatureC'             :'temperature',
                'Min TemperatureC'              :'temperature_min',
                'Dew PointC'                    :'dewpoint_max',
                'MeanDew PointC'                :'dewpoint',
                'Min DewpointC'                 :'dewpoint_min',
                'Max Humidity'                  :'humidity_max',
                ' Mean Humidity'                :'humidity',
                ' Min Humidity'                 :'humidity_min',
                ' Max Sea Level PressurehPa'    :'pressure_max',
                ' Mean Sea Level PressurehPa'   :'pressure',
                ' Min Sea Level PressurehPa'    :'pressure_min',
                ' Max VisibilityKm'             :'visibility_max',
                ' Mean VisibilityKm'            :'visibility',
                ' Min VisibilitykM'             :'visibility_min',
                ' Max Wind SpeedKm/h'           :'windspeed_max',
                ' Mean Wind SpeedKm/h'          :'windspeed',
                ' Max Gust SpeedKm/h'           :'gustspeed',      
                'Precipitationmm'               :'precipitation',
                ' CloudCover'                   :'cloudcover',
                ' Events'                       :'events',
                'WindDirDegrees'                :'winddirection',
                }

df.rename(columns=rename_dict, inplace=True)
df.sample(5).T
# Out:
#                       6622       173        1535       5736       5734
# date             2015-6-25  1997-6-23  2001-6-21  2013-1-20  2013-1-18
# temperature_max         33         28         37          9         13
# temperature             24         19         26          6         11
# temperature_min         16         11         15          3          8
# dewpoint_max            14         10          5          6         11
# dewpoint                 9          8          2          1          9
# dewpoint_min             2          5         -3         -2          6
# humidity_max            77         67         48        100         94
# humidity                37         46         24         69         86
# humidity_min             9         32          9         42         71
# pressure_max          1023       1018       1019       1006       1013
# pressure              1020       1017       1017       1001       1008
# pressure_min          1015       1015       1015        992        999
# visibility_max          31         10        NaN         31         31
# visibility              22         10        NaN         11         11
# visibility_min          10         10        NaN         10         10
# windspeed_max           14         11         16         32         42
# windspeed                6          3          6         19         24
# gustspeed               37        NaN        NaN         53         61
# precipitation            0          0          0       0.25          0
# cloudcover               1          1        NaN          3          5
# events                 NaN        NaN        NaN       Rain        NaN
# winddirection          194         28        360        249        227

# %%
df.describe().T
# Out:
#                   count         mean         std  ...     50%      75%     max
# temperature_max  6810.0    21.039648    8.867187  ...    20.0    29.00    41.0
# temperature      6809.0    14.658687    7.580461  ...    14.0    21.00    32.0
# temperature_min  6810.0     8.640529    6.837626  ...     9.0    14.00    28.0
# dewpoint_max     6810.0     8.120705    4.741067  ...     8.0    12.00    20.0
# dewpoint         6810.0     4.976211    4.654270  ...     6.0     8.00    16.0
# dewpoint_min     6810.0     1.451248    4.909705  ...     2.0     5.00    14.0
# humidity_max     6810.0    81.139354   17.531839  ...    87.0    94.00   100.0
# humidity         6810.0    57.971366   19.675744  ...    59.0    74.00   100.0
# humidity_min     6810.0    34.729369   19.320359  ...    32.0    47.75   100.0
# pressure_max     6812.0  1020.529360    6.235941  ...  1020.0  1024.00  1047.0
# pressure         6812.0  1017.973136    6.480085  ...  1018.0  1022.00  1043.0
# pressure_min     6812.0  1015.217410    6.944745  ...  1015.0  1019.00  1041.0
# visibility_max   5872.0    14.644074    8.770024  ...    10.0    10.00    31.0
# visibility       5872.0    11.719857    5.592324  ...    10.0    10.00    31.0
# visibility_min   5872.0     9.134877    5.075065  ...    10.0    10.00    31.0
# windspeed_max    6812.0    21.953171    9.903914  ...    21.0    27.00   182.0
# windspeed        6812.0     9.170728    5.110013  ...     8.0    11.00    39.0
# gustspeed        3506.0    43.988306   12.252462  ...    42.0    52.00   103.0
# precipitation    6812.0     0.111182    0.967174  ...     0.0     0.00    32.0
# cloudcover       5440.0     3.206066    1.808948  ...     3.0     5.00     8.0
# winddirection    6812.0   197.234586  119.872777  ...   223.0   299.00   360.0
#
# [21 rows x 8 columns]

# %% [markdown]
# Process dates

# %%
# convert string to datetime
df.date = df.date.apply(lambda x: datetime.strptime(x,'%Y-%m-%d'))

# 127 dates are missing, most of them in 2000 but also some in January 2004:  
existing_dates = list(df.date) 
for i in range(6939):
    d = df.date.iloc[0] + np.timedelta64(i, 'D')
    if not d in existing_dates:
        print(d)
# Out:
# 2000-02-23 00:00:00
# 2000-02-24 00:00:00
# 2000-02-25 00:00:00
# 2000-02-26 00:00:00
# 2000-02-27 00:00:00
# 2000-02-28 00:00:00
# 2000-02-29 00:00:00
# 2000-03-01 00:00:00
# 2000-03-02 00:00:00
# 2000-03-03 00:00:00
# 2000-03-04 00:00:00
# 2000-03-05 00:00:00
# 2000-03-06 00:00:00
# 2000-03-07 00:00:00
# 2000-03-08 00:00:00
# 2000-03-09 00:00:00
# 2000-03-10 00:00:00
# 2000-03-11 00:00:00
# 2000-03-12 00:00:00
# 2000-03-13 00:00:00
# 2000-03-14 00:00:00
# 2000-03-15 00:00:00
# 2000-03-16 00:00:00
# 2000-03-17 00:00:00
# 2000-03-18 00:00:00
# 2000-03-19 00:00:00
# 2000-03-20 00:00:00
# 2000-03-21 00:00:00
# 2000-03-22 00:00:00
# 2000-03-23 00:00:00
# 2000-03-24 00:00:00
# 2000-03-25 00:00:00
# 2000-03-26 00:00:00
# 2000-03-27 00:00:00
# 2000-03-28 00:00:00
# 2000-03-29 00:00:00
# 2000-03-30 00:00:00
# 2000-03-31 00:00:00
# 2000-04-01 00:00:00
# 2000-04-02 00:00:00
# 2000-04-03 00:00:00
# 2000-04-04 00:00:00
# 2000-04-05 00:00:00
# 2000-04-06 00:00:00
# 2000-04-07 00:00:00
# 2000-04-08 00:00:00
# 2000-04-09 00:00:00
# 2000-04-10 00:00:00
# 2000-04-11 00:00:00
# 2000-04-12 00:00:00
# 2000-04-13 00:00:00
# 2000-04-14 00:00:00
# 2000-04-15 00:00:00
# 2000-04-16 00:00:00
# 2000-04-17 00:00:00
# 2000-04-18 00:00:00
# 2000-04-19 00:00:00
# 2000-04-20 00:00:00
# 2000-04-21 00:00:00
# 2000-04-22 00:00:00
# 2000-04-23 00:00:00
# 2000-04-24 00:00:00
# 2000-04-25 00:00:00
# 2000-04-26 00:00:00
# 2000-04-27 00:00:00
# 2000-04-28 00:00:00
# 2000-04-29 00:00:00
# 2000-04-30 00:00:00
# 2000-05-01 00:00:00
# 2000-05-02 00:00:00
# 2000-05-03 00:00:00
# 2000-06-02 00:00:00
# 2000-06-03 00:00:00
# 2000-06-04 00:00:00
# 2000-06-05 00:00:00
# 2000-06-06 00:00:00
# 2000-06-07 00:00:00
# 2000-06-08 00:00:00
# 2000-06-09 00:00:00
# 2000-08-12 00:00:00
# 2000-08-13 00:00:00
# 2000-08-14 00:00:00
# 2000-08-15 00:00:00
# 2000-08-16 00:00:00
# 2000-08-17 00:00:00
# 2000-08-18 00:00:00
# 2000-08-19 00:00:00
# 2000-08-20 00:00:00
# 2000-08-21 00:00:00
# 2000-08-23 00:00:00
# 2000-08-24 00:00:00
# 2000-08-25 00:00:00
# 2000-08-26 00:00:00
# 2000-08-28 00:00:00
# 2000-08-29 00:00:00
# 2000-08-30 00:00:00
# 2000-08-31 00:00:00
# 2004-01-02 00:00:00
# 2004-01-03 00:00:00
# 2004-01-04 00:00:00
# 2004-01-05 00:00:00
# 2004-01-06 00:00:00
# 2004-01-07 00:00:00
# 2004-01-08 00:00:00
# 2004-01-09 00:00:00
# 2004-01-10 00:00:00
# 2004-01-11 00:00:00
# 2004-01-12 00:00:00
# 2004-01-13 00:00:00
# 2004-01-14 00:00:00
# 2004-01-15 00:00:00
# 2004-01-16 00:00:00
# 2004-01-17 00:00:00
# 2004-01-18 00:00:00
# 2004-01-19 00:00:00
# 2004-01-20 00:00:00
# 2004-01-21 00:00:00
# 2004-01-22 00:00:00
# 2004-01-23 00:00:00
# 2004-01-24 00:00:00
# 2004-01-25 00:00:00
# 2004-01-26 00:00:00
# 2004-01-27 00:00:00
# 2004-01-28 00:00:00
# 2004-01-29 00:00:00
# 2004-01-30 00:00:00
# 2004-01-31 00:00:00

# %%
# Contiguous data starts from Feb 1, 2004, truncate the dataset accordingly:
df = df[2460:]
df.head()
# Out:
#            date  temperature_max  temperature  ...  cloudcover  events  winddirection
# 2460 2004-02-01             12.0          9.0  ...         7.0     Fog            347
# 2461 2004-02-02             15.0         11.0  ...         5.0     NaN            353
# 2462 2004-02-03             17.0         10.0  ...         0.0     Fog            351
# 2463 2004-02-04             19.0         11.0  ...         0.0     NaN            359
# 2464 2004-02-05             19.0         11.0  ...         0.0     NaN            359
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Impute missing

# %%
df.isna().sum()
# Out:
# date                  0
# temperature_max       0
# temperature           0
# temperature_min       0
# dewpoint_max          0
# dewpoint              0
# dewpoint_min          0
# humidity_max          0
# humidity              0
# humidity_min          0
# pressure_max          0
# pressure              0
# pressure_min          0
# visibility_max      630
# visibility          630
# visibility_min      630
# windspeed_max         0
# windspeed             0
# gustspeed          1400
# precipitation         0
# cloudcover         1050
# events             3229
# winddirection         0
# dtype: int64

# %%
df[df.visibility.isna()].sample(2)
# Out:
#            date  temperature_max  temperature  ...  cloudcover  events  winddirection
# 4890 2010-09-27             23.0         16.0  ...         NaN     NaN             65
# 2938 2005-05-24             30.0         20.0  ...         NaN     NaN            114
#
# [2 rows x 23 columns]

# %%
df.visibility.value_counts().sort_index()
# Out:
# 1.0        2
# 2.0        5
# 3.0        8
# 4.0       24
# 5.0       41
# 6.0       48
# 7.0       76
# 8.0      139
# 9.0      284
# 10.0    1849
# 11.0      93
# 12.0     112
# 13.0      80
# 14.0      74
# 15.0      65
# 16.0      60
# 17.0      76
# 18.0      46
# 19.0      52
# 20.0      44
# 21.0      46
# 22.0      46
# 23.0      31
# 24.0      37
# 25.0      16
# 26.0      30
# 27.0      28
# 28.0      33
# 29.0      40
# 30.0      93
# 31.0     144
# Name: visibility, dtype: int64

# %%
# impute missing visibility with the Mode of visibility=10 (about 50% )
for col in df.columns[13:16]:
    df[col].fillna(10, inplace=True)

# %%
# gustspeed, cloudcover -- remove the features b/c:
#    - missing values do not appear to follow any pattern 
#    - these features seem secondary in the context of at least 1-day ahead prediction
df.drop(['gustspeed','cloudcover'], axis=1, inplace=True)

# %%
# Events: categories too granular, likely to introduce noise
df.events.value_counts(dropna=False).sort_index()
# Out:
# Fog                        131
# Fog-Rain                    41
# Fog-Rain-Snow                1
# Fog-Snow                     4
# Rain                       733
# Rain-Hail                    1
# Rain-Hail-Thunderstorm       5
# Rain-Snow                   27
# Rain-Snow-Thunderstorm       1
# Rain-Thunderstorm          150
# Snow                         8
# Thunderstorm                21
# NaN                       3229
# Name: events, dtype: int64

# %%
# Leave just 1 large category -  Rain with all its variants (~90% of non-empty events)
# Replace Rain:1, everything else: 0
df.events = [1 if 'Rain' in str(event) else 0 for event in df.events]
df.rename(columns={'events':'rain'}, inplace=True)

# %%
df.isna().sum()
# Out:
# date               0
# temperature_max    0
# temperature        0
# temperature_min    0
# dewpoint_max       0
# dewpoint           0
# dewpoint_min       0
# humidity_max       0
# humidity           0
# humidity_min       0
# pressure_max       0
# pressure           0
# pressure_min       0
# visibility_max     0
# visibility         0
# visibility_min     0
# windspeed_max      0
# windspeed          0
# precipitation      0
# rain               0
# winddirection      0
# dtype: int64

# %% [markdown]
# ### EDA

# %%
# helper plot function
def plot_series(series_dict, start=0, t=df.date):
    """Args: 
         t, array-like of timesteps (x axis)
         series_dist, dict of {'series_name': series}
         view, optional tuple or list of (t_start, t_end)         
    """
    plt.figure(figsize=(16,6))
    for label, series in series_dict.items():
        plt.plot(t[start:], series[start:], label=label)
    plt.legend()
    plt.show()

# %%
plot_series({'Avg Temp': df.temperature})

# %%
for f in ['temperature','dewpoint','humidity','pressure','visibility']:
    plot_series({f'Max {f}': df[f'{f}_max'], 
                 f'Avg {f}': df[f], 
                 f'Min {f}': df[f'{f}_min']}, 
                -365)

# %%
# remove min and max, they would introduce collinearity, especially given little data (only 4,352 data points)
# keep only averages
for f in ['temperature','dewpoint','humidity','pressure','visibility']:
    df.drop([f'{f}_max', f'{f}_min'], axis=1, inplace=True)

# %%
# same for wind speed - remove max:
plot_series({'windspeed_max': df.windspeed_max, 'windspeed': df.windspeed}, -365)

# %%
df.drop('windspeed_max', axis=1, inplace=True)

# %%
df.head()
# Out:
#            date  temperature  dewpoint  ...  precipitation  rain  winddirection
# 2460 2004-02-01          9.0       8.0  ...            0.0     0            347
# 2461 2004-02-02         11.0       7.0  ...            0.0     0            353
# 2462 2004-02-03         10.0       5.0  ...            0.0     0            351
# 2463 2004-02-04         11.0       6.0  ...            0.0     0            359
# 2464 2004-02-05         11.0       5.0  ...            0.0     0            359
#
# [5 rows x 10 columns]

# %%
def plot_feature(f):
    _, (ax0,ax1) = plt.subplots(1, 2, figsize=(12, 4))
    sns.distplot(df[f], ax=ax0)
    ax0.set_title(f)
    sns.regplot(y='temperature', x=f, data=df, ax=ax1, marker='.')
    ax1.set_title(f'{f} vs temperature')
    plt.show()

for f in df.columns[1:]:
    plot_feature(f)

# %%
plt.figure(figsize=(8,4))
sns.heatmap(df.drop('date', axis=1).corr(), cmap='coolwarm_r')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Workflow

# %% [markdown]
# The general workflow:
# 1. Select a single target (e.g. temperature). Do not optimize a whole vector.
# 2. Decide on the metric: MAE(y_true,y_hat), but not MAPE b/c 0 degrees
# 3. Copy the target variable into a separate tensor Y
# 4. Predictors X include the target Y.  Remove the date from X
# 5. Split the timeline into non-overlapping consecutive train and test. E.g. test the last 365 days of data (year 2015)
# 6. Leakage control: distort the last observation
# 7. Fit and predict 1 Horizon ahead, for both univariate and multivariate models:
#     - SARIMA
#     - RNNs
# 8. Explore residuals correlations, build ensemble models

# %%
TARGET = 'temperature'

TEST_PERIOD = -365   # last days of the target

HORIZON = 1  # forecast horizon (e.g. for 1-day ahead forecasts, horizon=1)

PERIOD = 365  # differencing period for SARIMA

y = df[TARGET].values.copy()
y_true  = y[TEST_PERIOD:].copy()
y_train = y[:TEST_PERIOD].copy()

t_train = df.date[:TEST_PERIOD]

y_hats = []  # accumulate the forecasts

# %%
reports = pd.DataFrame(columns=['target', 'var', 'horizon', 'forecast', 'MAE'])
reports
# Out:
# Empty DataFrame
# Columns: [target, var, horizon, forecast, MAE]
# Index: []

# %% [markdown]
# **Leakage control**
#
# In a leakage-proof model, the last observation cannot influence the last prediction.
# - distort the last actual observation, e.g increase the target y[-1] by x1000000
# - for each model, check that y_hat[-1] is not affected and is within reasonable range

# %%
y[-1] *= 1_000_000

print(y[-1])
print(y_true[-1])
# Out:
# 10000000.0
# 10.0

# %% [markdown]
# # Benchmarks

# %% [markdown]
# **1. Naive**
#
# The basic benchmark is Naive forecast S(t)=S(t-1)

# %%
def naive_forecast(series, test_period=TEST_PERIOD, horizon=HORIZON):
    return series[test_period-horizon : -horizon]

y_hat = naive_forecast(y)
y_hats.append(y_hat)
y_hat[-5:] # leakage control
# Out:
# array([6., 7., 8., 8., 8.])

# %%
reports.loc[len(reports)] = [TARGET, 'uni', HORIZON, 'Naive S(t)=S(t-1)', MAE(y_true, y_hat)]
reports
# Out:
#         target  var horizon           forecast       MAE
# 0  temperature  uni       1  Naive S(t)=S(t-1)  1.528767

# %%
plot_series({f'{TARGET}': y_true,  'Naive S(t)=S(t-1)': y_hat}, TEST_PERIOD)

# %%
# check naive forecast error for n-day ahead horizons
for h in range(1,11):
    print(h, MAE(y_true, naive_forecast(y, horizon=h)))
# Out:
# 1 1.5287671232876712
# 2 2.1397260273972605
# 3 2.558904109589041
# 4 2.6986301369863015
# 5 2.7835616438356166
# 6 2.756164383561644
# 7 2.778082191780822
# 8 2.8383561643835615
# 9 2.947945205479452
# 10 3.0767123287671234

# %% [markdown]
# **2. Moving average differenced**
#
# A slightly less naive approach, applicable only for periodic series, relies on smoothing the signal as compared to previous periods:
# S(t) = MA[S(t-1)-S(t-1-period)] + S(t-period)

# %%
def ma_trailing(series, window):
    """ Produce a trailing moving average over a fixed period length (window)
        The trailing MA does NOT include the last observation to prevent leakage
    """
    series, window = np.array(series), int(window)
    return np.array([np.nanmean(series[t-window:t]) for t in range(window, len(series))])

# %%
window = 7 #e.g. weekly moving average
plot_series({f'{TARGET}': y_true, f'MA {window}': ma_trailing(y, window)}, TEST_PERIOD)

# %%
def diff_forecast(series, ma_window, period=PERIOD, split_time=TEST_PERIOD):
    """ Implements period-based  differencing: 
        S_hat(t) =  S(t-period) +  MA_ma_window [S(t)-S(t-period)]  <-- no leakage from S(t)!
        NB: works well only for strictly periodic series such as 24 hours or 365 days
    """
    diff_series = (series[period:]-series[:-period]) # S(t)-S(t-period)
    return series[split_time-period:-period] + ma_trailing(diff_series, ma_window)[split_time:]

# %%
# the simplest MA diff forecast is window=1: S(t) = S(t-1) - S(t-1-period) + S(t-period)
y_hat = diff_forecast(y, ma_window=1)
y_hats.append(y_hat)
y_hat[-5:] # leakage control
# Out:
# array([ 4., 10.,  6.,  6.,  7.])

# %%
reports.loc[len(reports)] = [TARGET, 'uni', HORIZON, 'MA differenced', MAE(y_true, y_hat)]
reports
# Out:
#         target  var horizon           forecast       MAE
# 0  temperature  uni       1  Naive S(t)=S(t-1)  1.528767
# 1  temperature  uni       1     MA differenced  2.172603

# %%
plot_series({f'{TARGET}': y_true,  'MA differenced': y_hat}, TEST_PERIOD)

# %%
# check MA differenced forecast error for different MA windows
for w in range(1,10):
    print(w, MAE(y_true, diff_forecast(y, w)))
# Out:
# 1 2.1726027397260275
# 2 2.378082191780822
# 3 2.4794520547945207
# 4 2.5136986301369864
# 5 2.591780821917808
# 6 2.636986301369863
# 7 2.66027397260274
# 8 2.672945205479452
# 9 2.690715372907154

# %% [markdown]
# Conclusion: naive forecast is more accurate than differenced

# %% [markdown]
# # SARIMA

# %% [markdown]
# ### Autocorrelations

# %% [markdown]
# At least 1 differencing is necessary to make the temperature series stationary:
# - 365-day period i.e. D=1 in SARIMA
# - potentially, extra differencing to eliminate secular trends if any i.e. d=0 or 1 -- optimize through grid search

# %%
def differenced(series, period):
    return series[period:] - series[:-period]

# %%
D_y = differenced(y, PERIOD)
print(D_y.shape)

D_train = differenced(y_train, PERIOD)
print(D_train.shape)
# Out:
# (3987,)
# (3622,)

# %%
# Basic regression slope
# The trend is significant (~0.12 C/year) -- de-trend with d=1 differencing
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(np.arange(len(y_train)).reshape(-1, 1), y_train)
print(365*reg.coef_)
# Out:
# [0.1168491]

# %%
plot_series({f'{TARGET} diff {PERIOD}': D_train, 
             f'mean={np.nanmean(D_train):.4f}': np.full(len(D_train), np.nanmean(D_train))}, 
            t=t_train[PERIOD:])

# %%
# the distribution of differences is platykurtic -- not white noise, this is good news
print(np.nanmean(D_train))
print(np.nanstd(D_train))
print(stats.skew(D_train))
print(stats.kurtosis(D_train))
# Out:
# 0.19160684704583103
# 4.027755198669093
# -0.04276631210327087
# -0.20274168781504764

# %%
_, (ax0,ax1) = plt.subplots(1, 2, figsize=(16, 5))
D_train_norm = (D_train-np.mean(D_train))/np.std(D_train)
sns.distplot(D_train_norm, bins=25, color='k', kde=False, norm_hist=True, ax=ax0, label='Actual')
ax0.plot(np.arange(-4,4,0.01), stats.norm.pdf(np.arange(-4,4,0.01)), 'r', lw=1, label='Normal')
ax0.set_xlim(-4,4)
ax0.set_title(f'{TARGET} diff {PERIOD}: normalized distribution')
ax0.legend()
qqplot(D_train, line='q', fit=True, color='k', marker='.', ax=ax1)
ax1.set_title(f'{TARGET} diff {PERIOD}: Q-Q plot')
plt.show()

# %%
# PACF plot indicates an AR(1) process
_, (ax0,ax1) = plt.subplots(1, 2, figsize=(16, 5))
plot_pacf(D_train, lags=30, ax=ax0)
plot_acf (D_train, lags=30, ax=ax1)
plt.show()

# %% [markdown]
# ### Univariate

# %%
# SARIMA basic (p,d,q)(P,D,Q,s) assumption:
# (P,D,Q) = (0,1,0,365) -- already differenced with period 365
# (p,d,q) = (1,?,?) -- p,d,q grid search

# %%
def sarima(diff_series, order, series=y):
    
    model = ARIMA(diff_series[:TEST_PERIOD], order=order)
    results = model.fit()    
    
    extended_results = results.extend(endog=diff_series[TEST_PERIOD:])    
    D_forecast = extended_results.forecasts[0]

    y_hat = D_forecast + y[TEST_PERIOD-PERIOD:TEST_PERIOD]

    return y_hat

# %% [markdown]
# The simplest AR(1) works better than any other order:

# %%
for order in [(1,0,0),
              (2,0,0),
              (1,1,0),
              (2,1,0),              
              (1,0,1),
              (1,1,1),
              (2,1,1),
              ]:
    y_hat = sarima(D_y, order=order)
    print(MAE(y_true, y_hat))
# Out:
# 2.0873346793301204
# 2.091868659326064
# 2.1782794440013995
# 2.153517996392519
# 2.0912000742490844
# 2.0896692964617722
# 2.1011504539699124

# %%
y_hat = sarima(D_y, order=(1,0,0))
y_hats.append(y_hat)
y_hat[-5:] # leakage control
# Out:
# array([4.04537957, 9.30317875, 5.7979793 , 5.30317875, 5.8083782 ])

# %%
reports.loc[len(reports)] = [TARGET, 'uni', HORIZON, 'SARIMA (1,0,0)(0,1,0,365)', MAE(y_true, y_hat)]
reports
# Out:
#         target  var horizon                   forecast       MAE
# 0  temperature  uni       1          Naive S(t)=S(t-1)  1.528767
# 1  temperature  uni       1             MA differenced  2.172603
# 2  temperature  uni       1  SARIMA (1,0,0)(0,1,0,365)  2.087335

# %%
plot_series({f'{TARGET}': y_true, 'SARIMA (1,0,0)(0,1,0,365)': y_hat}, TEST_PERIOD)

# %% [markdown]
# Verify if incremental retraining on S[:-t] adds forecast accuracy for S[t+1]

# %%
def sarima_incremental(diff_series, order, series=y):
    tic = time.time()
    y_hat=np.zeros(-TEST_PERIOD)
    
    for t in range(TEST_PERIOD,0):
        model = ARIMA(diff_series[:t], order=order)
        results = model.fit()
        D_forecast = results.forecast(steps=1)[0]

        y_hat[t-TEST_PERIOD]  = D_forecast + series[t-PERIOD]

        toc = time.time()
        print(f'\r {t} in {toc-tic:.1f} sec', end='')
    return y_hat

# %%
y_hat = sarima_incremental(D_y, order=(1,0,0))
y_hats.append(y_hat)
y_hat[-5:] # leakage control
# Out:
#  -1 in 90.0 sec
# array([4.04096572, 9.29216495, 5.79238103, 5.29231429, 5.79405502])

# %%
reports.loc[len(reports)] = [TARGET, 'uni', HORIZON, 'Incremental SARIMA (1,0,0)(0,1,0,365)', MAE(y_true, y_hat)]
reports
# Out:
#         target  var horizon                               forecast       MAE
# 0  temperature  uni       1                      Naive S(t)=S(t-1)  1.528767
# 1  temperature  uni       1                         MA differenced  2.172603
# 2  temperature  uni       1              SARIMA (1,0,0)(0,1,0,365)  2.087335
# 3  temperature  uni       1  Incremental SARIMA (1,0,0)(0,1,0,365)  2.088545

# %% [markdown]
# Conclusion: Incremental retraining every day during the TEST_PERIOD does NOT add accuracy. Apparently, the model trained on 2004-2014 already extracted any linear patterns present in the data.

# %% [markdown]
# ### Multivariate

# %%
exog = list(df.columns)
exog.remove('date')
exog.remove(TARGET)
exog_data = df[exog].values

normalize = False
if normalize:
    scaler = StandardScaler()
    exog_data = scaler.fit_transform(exog_data)

# %%
def sarima_x(diff_series, order, series=y):
    
    model = ARIMA(diff_series[:TEST_PERIOD], order=order, exog=exog_data[PERIOD:TEST_PERIOD])
    results = model.fit()    
    
    extended_results = results.extend(endog=diff_series[TEST_PERIOD:], exog=exog_data[TEST_PERIOD:])
    D_forecast = extended_results.forecasts[0]

    y_hat = D_forecast + y[TEST_PERIOD-PERIOD:TEST_PERIOD]

    return y_hat

# %%
# search for the best (p,d,q)
for order in [(1,0,0),
              (2,0,0),
              (1,1,0),
              (2,1,0),              
              (1,0,1),
              (1,1,1),
              (2,1,1),
              ]:
    y_hat = sarima_x(D_y, order=order)
    print(MAE(y_true, y_hat))
# Out:
# 1.91008146999505
# 1.888930189928541
# 1.8458803390009872
# 1.8384214767279792
# 1.916879611422112
# 1.8407014682336573
# 1.7957896941171583

# %%
y_hat = sarima_x(D_y, order=(2,1,1))
y_hats.append(y_hat)
y_hat[-5:] # leakage control
# Out:
# array([ 5.63366007, 11.36436003,  6.18226407,  5.23224443,  7.72802999])

# %%
reports.loc[len(reports)] = [TARGET, 'multi', HORIZON, 'Multivariate SARIMAX (2,1,1)(0,1,0,365)', MAE(y_true, y_hat)]
reports
# Out:
#         target    var  ...                                 forecast       MAE
# 0  temperature    uni  ...                        Naive S(t)=S(t-1)  1.528767
# 1  temperature    uni  ...                           MA differenced  2.172603
# 2  temperature    uni  ...                SARIMA (1,0,0)(0,1,0,365)  2.087335
# 3  temperature    uni  ...    Incremental SARIMA (1,0,0)(0,1,0,365)  2.088545
# 4  temperature  multi  ...  Multivariate SARIMAX (2,1,1)(0,1,0,365)  1.795790
#
# [5 rows x 5 columns]

# %%
plot_series({f'{TARGET}': y_true, 'Multivariate SARIMAX (2,1,1)(0,1,0,365)': y_hat}, TEST_PERIOD)

# %% [markdown]
# Multivariate SARIMAX observations:
# - exogenous regressors improve accuracy
# - unlike in univariate SARIMA, higher order (2,1,1) works better
# - the best SARIMAX is still worse than the naive forecast

# %% [markdown]
# # LSTM

# %% [markdown]
# ### Univariate

# %%
WINDOW_SIZE = 365
BATCH_SIZE  = 32
SHUFFLE_BUFFER = 1024
SPLIT_DS = 0.9

EPOCHS = 50

# %%
def rnn_dataset(series,
                target_index=0, 
                window_size=WINDOW_SIZE, 
                batch_size=BATCH_SIZE, 
                shuffle_buffer=SHUFFLE_BUFFER,
                split=SPLIT_DS,
                ):
    
    # Input tensor to RNN must have the shape (batch, timesteps, features). If univariate, add feature dimension
    if series.ndim==1: series = series[..., np.newaxis]
    
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(window_size+1, shift=1, drop_remainder=True)
    dataset = dataset.flat_map(lambda w: w.batch(window_size+1))
    dataset = dataset.shuffle(shuffle_buffer)

    split = int(split*series.shape[0])
    train_ds = dataset.take(split).map(lambda w: (w[:-1], w[1:,target_index])).batch(batch_size)
    val_ds   = dataset.skip(split).map(lambda w: (w[:-1], w[1:,target_index])).batch(batch_size)

    return train_ds, val_ds

def rnn_forecast(model, 
                 series, 
                 window_size=WINDOW_SIZE, 
                 batch_size=BATCH_SIZE, 
                 ):
    
    if series.ndim==1: series = series[..., np.newaxis]

    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)
    dataset = dataset.flat_map(lambda w: w.batch(window_size))
    dataset = dataset.batch(batch_size)
    
    return model.predict(dataset)    

def scheduler(epoch, lr):
    # keep the original lr for flat_period epochs, exponential decay since then subject to floor_lr
    flat_period, decay, floor_lr = 5, -0.1, 1e-4
    if epoch<=flat_period: 
        return lr
    return max(lr*np.exp(decay), floor_lr)
   
lr_callback=callbacks.LearningRateScheduler(scheduler, verbose=1) 
es_callback=callbacks.EarlyStopping(monitor='val_mae', verbose=0, patience=4, mode='min')

# %%
train_ds, val_ds = rnn_dataset(y_train)
train_ds.element_spec
# Out:
# (TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None),
#  TensorSpec(shape=(None, None), dtype=tf.float64, name=None))

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(32, input_shape=[None, 1], return_sequences=True),
    tf.keras.layers.Dense(16, activation="relu"),
    tf.keras.layers.Dense(1)
])

model.compile(loss='mae',   
              optimizer=Adam(),
              metrics=['mae'])

model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_14 (LSTM)               (None, None, 32)          4352
# _________________________________________________________________
# dense_28 (Dense)             (None, None, 16)          528
# _________________________________________________________________
# dense_29 (Dense)             (None, None, 1)           17
# =================================================================
# Total params: 4,897
# Trainable params: 4,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_ds, 
                    epochs=EPOCHS,  
                    validation_data=val_ds,
                    callbacks=[lr_callback, es_callback],
                    verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/50
# 113/113 [==============================] - 3s 23ms/step - loss: 10.3141 - mae: 10.3141 - val_loss: 5.4821 - val_mae: 5.4821
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/50
# 113/113 [==============================] - 2s 20ms/step - loss: 2.4800 - mae: 2.4800 - val_loss: 1.6266 - val_mae: 1.6266
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/50
# 113/113 [==============================] - 2s 21ms/step - loss: 1.5629 - mae: 1.5629 - val_loss: 1.5332 - val_mae: 1.5332
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/50
# 113/113 [==============================] - 2s 21ms/step - loss: 1.5084 - mae: 1.5084 - val_loss: 1.5129 - val_mae: 1.5129
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 5/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4878 - mae: 1.4878 - val_loss: 1.4953 - val_mae: 1.4953
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 6/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4779 - mae: 1.4779 - val_loss: 1.4850 - val_mae: 1.4850
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009048374610134307.
# Epoch 7/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4680 - mae: 1.4680 - val_loss: 1.4599 - val_mae: 1.4599
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0008187307807475673.
# Epoch 8/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4601 - mae: 1.4601 - val_loss: 1.4649 - val_mae: 1.4649
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0007408182609837606.
# Epoch 9/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4545 - mae: 1.4545 - val_loss: 1.4658 - val_mae: 1.4658
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0006703200923609524.
# Epoch 10/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4490 - mae: 1.4490 - val_loss: 1.4493 - val_mae: 1.4493
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.000606530675391766.
# Epoch 11/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4435 - mae: 1.4435 - val_loss: 1.4501 - val_mae: 1.4501
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0005488116682245179.
# Epoch 12/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4393 - mae: 1.4393 - val_loss: 1.4526 - val_mae: 1.4526
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004965853504160465.
# Epoch 13/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4355 - mae: 1.4355 - val_loss: 1.4444 - val_mae: 1.4444
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004493289874054642.
# Epoch 14/50
# 113/113 [==============================] - 2s 21ms/step - loss: 1.4330 - mae: 1.4330 - val_loss: 1.4421 - val_mae: 1.4421
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004065696690041351.
# Epoch 15/50
# 113/113 [==============================] - 2s 22ms/step - loss: 1.4304 - mae: 1.4304 - val_loss: 1.4352 - val_mae: 1.4352
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.00036787943756223617.
# Epoch 16/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4279 - mae: 1.4279 - val_loss: 1.4373 - val_mae: 1.4373
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003328710744911885.
# Epoch 17/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4256 - mae: 1.4256 - val_loss: 1.4247 - val_mae: 1.4247
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00030119420279690575.
# Epoch 18/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4241 - mae: 1.4241 - val_loss: 1.4205 - val_mae: 1.4205
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0002725317846265655.
# Epoch 19/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4222 - mae: 1.4222 - val_loss: 1.4276 - val_mae: 1.4276
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0002465969611604322.
# Epoch 20/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4200 - mae: 1.4200 - val_loss: 1.4252 - val_mae: 1.4252
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0002231301558460287.
# Epoch 21/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4188 - mae: 1.4188 - val_loss: 1.4273 - val_mae: 1.4273
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00020189651997736023.
# Epoch 22/50
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4173 - mae: 1.4173 - val_loss: 1.4211 - val_mae: 1.4211

# %%
y_hat = rnn_forecast(model, y[TEST_PERIOD-WINDOW_SIZE:-1])
y_hat = np.squeeze(y_hat[:, -1, -1])
y_hats.append(y_hat)
y_hat[-5:] # leakage control
# Out:
# array([5.537038 , 6.1216497, 6.819483 , 6.911723 , 6.925954 ],
#       dtype=float32)

# %%
reports.loc[len(reports)] = [TARGET, 'uni', HORIZON, 'LSTM-32 Dense-16', MAE(y_true, y_hat)]
reports
# Out:
#         target    var  ...                                 forecast       MAE
# 0  temperature    uni  ...                        Naive S(t)=S(t-1)  1.528767
# 1  temperature    uni  ...                           MA differenced  2.172603
# 2  temperature    uni  ...                SARIMA (1,0,0)(0,1,0,365)  2.087335
# 3  temperature    uni  ...    Incremental SARIMA (1,0,0)(0,1,0,365)  2.088545
# 4  temperature  multi  ...  Multivariate SARIMAX (2,1,1)(0,1,0,365)  1.795790
# 5  temperature    uni  ...                         LSTM-32 Dense-16  1.539400
#
# [6 rows x 5 columns]

# %%
plot_series({f'{TARGET}': y_true, 'LSTM-32 Dense-16': y_hat}, TEST_PERIOD)

# %% [markdown]
# ### Multivariate

# %%
exog = list(df.columns)
exog.remove('date')
TARGET_INDEX = exog.index(TARGET)

exog_data = df[exog].values

normalize = False
if normalize:
    scaler = StandardScaler()
    exog_data = scaler.fit_transform(exog_data)

# %%
train_ds, val_ds = rnn_dataset(exog_data[:TEST_PERIOD], target_index=TARGET_INDEX)
train_ds.element_spec
# Out:
# (TensorSpec(shape=(None, None, 9), dtype=tf.float64, name=None),
#  TensorSpec(shape=(None, None), dtype=tf.float64, name=None))

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(512, input_shape=[None, exog_data.shape[1]], return_sequences=True),
    tf.keras.layers.Dense(16, activation="relu"),
    tf.keras.layers.Dense(1)
])

model.compile(loss='mae',   
              optimizer=Adam(),
              metrics=['mae'])

model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (None, None, 512)         1069056
# _________________________________________________________________
# dense_30 (Dense)             (None, None, 16)          8208
# _________________________________________________________________
# dense_31 (Dense)             (None, None, 1)           17
# =================================================================
# Total params: 1,077,281
# Trainable params: 1,077,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_ds, 
                    epochs=EPOCHS,  
                    validation_data=val_ds,
                    callbacks=[lr_callback, es_callback],
                    verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/50
# 113/113 [==============================] - 7s 65ms/step - loss: 6.0410 - mae: 6.0410 - val_loss: 2.7692 - val_mae: 2.7692
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/50
# 113/113 [==============================] - 7s 63ms/step - loss: 1.8533 - mae: 1.8533 - val_loss: 1.5292 - val_mae: 1.5292
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.4580 - mae: 1.4580 - val_loss: 1.4277 - val_mae: 1.4277
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.3814 - mae: 1.3814 - val_loss: 1.3571 - val_mae: 1.3571
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 5/50
# 113/113 [==============================] - 7s 63ms/step - loss: 1.3395 - mae: 1.3395 - val_loss: 1.3217 - val_mae: 1.3217
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 6/50
# 113/113 [==============================] - 7s 63ms/step - loss: 1.3138 - mae: 1.3138 - val_loss: 1.3150 - val_mae: 1.3150
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009048374610134307.
# Epoch 7/50
# 113/113 [==============================] - 7s 64ms/step - loss: 1.2976 - mae: 1.2976 - val_loss: 1.3191 - val_mae: 1.3191
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0008187307807475673.
# Epoch 8/50
# 113/113 [==============================] - 7s 63ms/step - loss: 1.2791 - mae: 1.2791 - val_loss: 1.2465 - val_mae: 1.2465
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0007408182609837606.
# Epoch 9/50
# 113/113 [==============================] - 7s 63ms/step - loss: 1.2596 - mae: 1.2596 - val_loss: 1.2448 - val_mae: 1.2448
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0006703200923609524.
# Epoch 10/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.2510 - mae: 1.2510 - val_loss: 1.2290 - val_mae: 1.2290
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.000606530675391766.
# Epoch 11/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.2402 - mae: 1.2402 - val_loss: 1.2168 - val_mae: 1.2168
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0005488116682245179.
# Epoch 12/50
# 113/113 [==============================] - 7s 61ms/step - loss: 1.2328 - mae: 1.2328 - val_loss: 1.2131 - val_mae: 1.2131
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004965853504160465.
# Epoch 13/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.2244 - mae: 1.2244 - val_loss: 1.2214 - val_mae: 1.2214
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004493289874054642.
# Epoch 14/50
# 113/113 [==============================] - 7s 61ms/step - loss: 1.2188 - mae: 1.2188 - val_loss: 1.1980 - val_mae: 1.1980
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004065696690041351.
# Epoch 15/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.2133 - mae: 1.2133 - val_loss: 1.1962 - val_mae: 1.1962
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.00036787943756223617.
# Epoch 16/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.2078 - mae: 1.2078 - val_loss: 1.1860 - val_mae: 1.1860
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003328710744911885.
# Epoch 17/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.2045 - mae: 1.2045 - val_loss: 1.1920 - val_mae: 1.1920
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00030119420279690575.
# Epoch 18/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.2000 - mae: 1.2000 - val_loss: 1.1693 - val_mae: 1.1693
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0002725317846265655.
# Epoch 19/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1957 - mae: 1.1957 - val_loss: 1.1807 - val_mae: 1.1807
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0002465969611604322.
# Epoch 20/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1921 - mae: 1.1921 - val_loss: 1.1764 - val_mae: 1.1764
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0002231301558460287.
# Epoch 21/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1886 - mae: 1.1886 - val_loss: 1.1658 - val_mae: 1.1658
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00020189651997736023.
# Epoch 22/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1868 - mae: 1.1868 - val_loss: 1.1569 - val_mae: 1.1569
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001826835231124296.
# Epoch 23/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1827 - mae: 1.1827 - val_loss: 1.1719 - val_mae: 1.1719
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.000165298885835805.
# Epoch 24/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1811 - mae: 1.1811 - val_loss: 1.1533 - val_mae: 1.1533
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00014956861785812693.
# Epoch 25/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1803 - mae: 1.1803 - val_loss: 1.1560 - val_mae: 1.1560
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00013533527995661116.
# Epoch 26/50
# 113/113 [==============================] - 7s 61ms/step - loss: 1.1773 - mae: 1.1773 - val_loss: 1.1662 - val_mae: 1.1662
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00012245643025519514.
# Epoch 27/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1746 - mae: 1.1746 - val_loss: 1.1490 - val_mae: 1.1490
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00011080316267450631.
# Epoch 28/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1741 - mae: 1.1741 - val_loss: 1.1408 - val_mae: 1.1408
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00010025884947215013.
# Epoch 29/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1717 - mae: 1.1717 - val_loss: 1.1638 - val_mae: 1.1638
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 30/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1700 - mae: 1.1700 - val_loss: 1.1289 - val_mae: 1.1289
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1676 - mae: 1.1676 - val_loss: 1.1342 - val_mae: 1.1342
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1666 - mae: 1.1666 - val_loss: 1.1376 - val_mae: 1.1376
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1644 - mae: 1.1644 - val_loss: 1.1332 - val_mae: 1.1332
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/50
# 113/113 [==============================] - 7s 62ms/step - loss: 1.1624 - mae: 1.1624 - val_loss: 1.1435 - val_mae: 1.1435

# %%
y_hat = rnn_forecast(model, exog_data[TEST_PERIOD-WINDOW_SIZE:-1])
y_hat = np.squeeze(y_hat[:, -1, -1])
y_hats.append(y_hat)
y_hat[-5:] # leakage control
# Out:
# array([6.2964   , 5.0980654, 7.4720306, 8.223842 , 8.126377 ],
#       dtype=float32)

# %%
reports.loc[len(reports)] = [TARGET, 'multi', HORIZON, 'Multivariate LSTM-512 Dense-16', MAE(y_true, y_hat)]
reports
# Out:
#         target    var  ...                                 forecast       MAE
# 0  temperature    uni  ...                        Naive S(t)=S(t-1)  1.528767
# 1  temperature    uni  ...                           MA differenced  2.172603
# 2  temperature    uni  ...                SARIMA (1,0,0)(0,1,0,365)  2.087335
# 3  temperature    uni  ...    Incremental SARIMA (1,0,0)(0,1,0,365)  2.088545
# 4  temperature  multi  ...  Multivariate SARIMAX (2,1,1)(0,1,0,365)  1.795790
# 5  temperature    uni  ...                         LSTM-32 Dense-16  1.539400
# 6  temperature  multi  ...           Multivariate LSTM-512 Dense-16  1.387362
#
# [7 rows x 5 columns]

# %%
plot_series({f'{TARGET}': y_true, 'Multivariate LSTM-512 Dense-16': y_hat}, TEST_PERIOD)

# %% [markdown]
# # Ensembles

# %%
reports
# Out:
#         target    var  ...                                 forecast       MAE
# 0  temperature    uni  ...                        Naive S(t)=S(t-1)  1.528767
# 1  temperature    uni  ...                           MA differenced  2.172603
# 2  temperature    uni  ...                SARIMA (1,0,0)(0,1,0,365)  2.087335
# 3  temperature    uni  ...    Incremental SARIMA (1,0,0)(0,1,0,365)  2.088545
# 4  temperature  multi  ...  Multivariate SARIMAX (2,1,1)(0,1,0,365)  1.795790
# 5  temperature    uni  ...                         LSTM-32 Dense-16  1.539400
# 6  temperature  multi  ...           Multivariate LSTM-512 Dense-16  1.387362
#
# [7 rows x 5 columns]

# %%
residuals = np.zeros((len(y_true), len(y_hats)))

for i, y_hat in enumerate(y_hats):
    residuals[:,i] =  y_hat-y_true

# %%
plt.figure(figsize=(8,4))
sns.heatmap(pd.DataFrame(columns=reports.forecast, data=residuals).corr(), cmap='coolwarm_r')
plt.title('Residuals correlation matrix')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Some forecasts are weakly correlated, therefore an ensemble model would reduce the variance, try a simple 50/50

# %%
for comb in [(0,4),
             (5,4),
             (6,4),
             (5,6),
             (5,1),
             (6,1),
             (4,5,6),             
             ]:
    if len(comb)==2: y_hat = (y_hats[comb[0]]+y_hats[comb[1]])/2
    if len(comb)==3: y_hat = (y_hats[comb[0]]+y_hats[comb[1]]+y_hats[comb[1]])/3
    print(comb, f'{MAE(y_true, y_hat):.4f}')
# Out:
# (0, 4) 1.3785
# (5, 4) 1.3713
# (6, 4) 1.2667
# (5, 6) 1.3889
# (5, 1) 1.7186
# (6, 1) 1.6049
# (4, 5, 6) 1.3560

# %%
# Ensemble of Multivariate SARIMAX and LSTM is optimal
y_hat = (y_hats[4]+y_hats[6])/2
y_hats.append(y_hat)
y_hat[-5:] # leakage control
# Out:
# array([5.96503007, 8.2312127 , 6.82714735, 6.72804305, 7.92720355])

# %%
reports.loc[len(reports)] = [TARGET, 'multi', HORIZON, 'Ensemble multivariate SARIMAX+RNN', MAE(y_true, y_hat)]
reports
# Out:
#         target    var  ...                                 forecast       MAE
# 0  temperature    uni  ...                        Naive S(t)=S(t-1)  1.528767
# 1  temperature    uni  ...                           MA differenced  2.172603
# 2  temperature    uni  ...                SARIMA (1,0,0)(0,1,0,365)  2.087335
# 3  temperature    uni  ...    Incremental SARIMA (1,0,0)(0,1,0,365)  2.088545
# 4  temperature  multi  ...  Multivariate SARIMAX (2,1,1)(0,1,0,365)  1.795790
# 5  temperature    uni  ...                         LSTM-32 Dense-16  1.539400
# 6  temperature  multi  ...           Multivariate LSTM-512 Dense-16  1.387362
# 7  temperature  multi  ...        Ensemble multivariate SARIMAX+RNN  1.266733
#
# [8 rows x 5 columns]

# %%
plot_series({f'{TARGET}': y_true, 'Ensemble multivariate SARIMAX+RNN': y_hat}, TEST_PERIOD)

# %% [markdown]
# # Compare Models

# %%
plt.figure(figsize=(10,4))
ax = sns.barplot(reports.MAE, reports.forecast, orient='h')

for i, mae in enumerate(reports.MAE):
    ax.text(mae, i+0.2, f'{mae:.2f}', fontsize=12)
plt.title(f'{TARGET} MAE -- OOS {-TEST_PERIOD} days')
plt.xlabel('')
plt.ylabel('')
plt.show()
